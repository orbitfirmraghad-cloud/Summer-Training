# %% [markdown]
# # **🦏 Exercise: Object Detection with YOLO**
# ---
#
# ### 🎯 Your Mission
# Train a YOLO model on the **African Wildlife** dataset and inspect how well it detects animals in the wild. 🦁🐘
#
# This is **your turn** — use everything from the walkthrough lab, but write the code yourself!
#
# ---
#
# ### 📂 The Dataset
# We'll use the **African Wildlife** dataset from Kaggle — **1,500 images** across **4 classes**:
#
# | ID | Class |
# |----|-------|
# | 0 | buffalo |
# | 1 | elephant |
# | 2 | rhino |
# | 3 | zebra |
#
#
# > 💡 The dataset is already in **YOLO format** (`images/`, `labels/`, and a `data.yaml`) — just like the lab.
#
# ---
#
# ### ✅ What You Need to Do
# 1. **Load** the dataset and inspect the `data.yaml`
# 2. **Load** a pretrained YOLOv26 model
# 3. **Train** the model on the dataset
# 4. **Evaluate** it on the validation set (check **mAP@0.5:0.95**)
# 5. **Run inference** on a few test images and **inspect the results** 👀
#
# ---
#
# ### 💡 Things to Think About
# - How do the predictions look **before vs. after** training?
# - Which animals does the model confuse most — and why might that be?
# - Would **more epochs** or a **larger image size** improve your scores?

# %% [markdown]
# #### Step 0 — (Colab only) Set the KaggleHub cache directory

# %%
# # Uncomment when running on Google Colab
# import os
# os.environ["KAGGLEHUB_CACHE"] = "/content/data"

# %% [markdown]
# #### Step 1 — Download / locate the dataset

# %%
import kagglehub
import os

os.environ["KAGGLEHUB_CACHE"] = ".\\"


# Download latest version
path = kagglehub.dataset_download("ankanghosh651/object-detection-wildlife-dataset-yolo-format")
path = os.path.join(path, "animals")
print("Path to dataset files:", path)
